# %%
#pip install -r ../requirements.txt

# %%
import pandas as pd
from transformers import AutoModelForSequenceClassification
import numpy as np
import evaluate
from transformers import TrainingArguments, Trainer,AutoTokenizer
import torch
from torch.utils.data import Dataset
from sklearn.metrics import roc_auc_score,roc_curve, auc,f1_score
from sklearn.model_selection import train_test_split
from sklearn import metrics
import matplotlib.pyplot as plt
import seaborn as sns
import scipy

# %%
model = AutoModelForSequenceClassification.from_pretrained("../models/diffcse-roberta-base-trans", local_files_only=True, num_labels=1)
metric = evaluate.load("accuracy")
training_args = TrainingArguments(output_dir="test_trainer", evaluation_strategy="epoch", num_train_epochs=7)
# Out:
# Some weights of the model checkpoint at ../models/diffcse-roberta-base-trans were not used when initializing RobertaForSequenceClassification: ['aux_bert.encoder.layer.1.intermediate.dense.bias', 'aux_bert.encoder.layer.10.attention.output.LayerNorm.weight', 'generator.roberta.encoder.layer.5.attention.self.value.weight', 'aux_bert.encoder.layer.9.output.dense.bias', 'generator.roberta.encoder.layer.0.attention.self.value.weight', 'aux_bert.encoder.layer.4.output.dense.weight', 'aux_bert.encoder.layer.7.attention.output.LayerNorm.weight', 'generator.roberta.encoder.layer.1.attention.self.value.bias', 'aux_bert.encoder.layer.2.attention.self.query.weight', 'aux_bert.encoder.layer.0.attention.self.query.weight', 'aux_bert.encoder.layer.10.output.dense.weight', 'aux_bert.encoder.layer.11.output.LayerNorm.weight', 'aux_bert.encoder.layer.4.attention.self.key.bias', 'generator.roberta.encoder.layer.0.output.LayerNorm.weight', 'mlp.net.4.num_batches_tracked', 'generator.roberta.encoder.layer.5.output.dense.weight', 'aux_bert.encoder.layer.10.attention.self.key.weight', 'generator.roberta.encoder.layer.2.output.LayerNorm.bias', 'generator.roberta.encoder.layer.0.attention.self.key.bias', 'aux_bert.embeddings.position_ids', 'aux_bert.encoder.layer.7.output.LayerNorm.weight', 'aux_bert.encoder.layer.0.attention.output.dense.weight', 'generator.lm_head.layer_norm.weight', 'aux_bert.encoder.layer.5.attention.output.dense.bias', 'aux_bert.encoder.layer.0.attention.output.LayerNorm.weight', 'aux_bert.encoder.layer.0.output.LayerNorm.bias', 'generator.roberta.encoder.layer.4.output.dense.bias', 'generator.roberta.encoder.layer.2.output.dense.weight', 'aux_bert.encoder.layer.1.output.LayerNorm.weight', 'generator.roberta.encoder.layer.5.attention.self.query.weight', 'aux_bert.encoder.layer.2.attention.self.value.weight', 'generator.roberta.encoder.layer.4.output.LayerNorm.weight', 'generator.roberta.embeddings.token_type_embeddings.weight', 'aux_bert.encoder.layer.7.attention.self.value.weight', 'generator.roberta.encoder.layer.2.attention.output.dense.bias', 'generator.roberta.encoder.layer.1.attention.self.key.weight', 'generator.roberta.encoder.layer.4.intermediate.dense.bias', 'generator.roberta.encoder.layer.4.attention.output.dense.bias', 'aux_bert.encoder.layer.1.attention.self.key.weight', 'aux_bert.encoder.layer.1.intermediate.dense.weight', 'aux_bert.encoder.layer.7.output.LayerNorm.bias', 'generator.roberta.encoder.layer.0.output.LayerNorm.bias', 'aux_bert.encoder.layer.2.attention.self.value.bias', 'aux_bert.encoder.layer.3.attention.output.LayerNorm.weight', 'aux_bert.encoder.layer.5.attention.output.LayerNorm.bias', 'generator.roberta.encoder.layer.5.attention.output.LayerNorm.weight', 'generator.roberta.embeddings.position_embeddings.weight', 'generator.roberta.encoder.layer.3.attention.self.key.weight', 'aux_bert.encoder.layer.7.output.dense.bias', 'generator.roberta.encoder.layer.0.output.dense.weight', 'aux_bert.encoder.layer.1.attention.self.key.bias', 'aux_bert.encoder.layer.0.output.dense.weight', 'aux_bert.encoder.layer.8.output.LayerNorm.bias', 'aux_bert.encoder.layer.10.attention.output.dense.bias', 'aux_bert.encoder.layer.8.intermediate.dense.weight', 'aux_bert.encoder.layer.6.output.LayerNorm.weight', 'generator.roberta.encoder.layer.1.output.LayerNorm.weight', 'aux_bert.encoder.layer.6.output.dense.weight', 'generator.lm_head.decoder.bias', 'aux_bert.encoder.layer.3.attention.self.key.weight', 'generator.roberta.embeddings.LayerNorm.weight', 'aux_bert.encoder.layer.1.attention.output.dense.weight', 'aux_bert.encoder.layer.10.attention.self.key.bias', 'aux_bert.encoder.layer.4.attention.output.dense.bias', 'generator.roberta.encoder.layer.3.attention.output.dense.weight', 'aux_bert.encoder.layer.2.attention.self.query.bias', 'generator.roberta.embeddings.word_embeddings.weight', 'generator.roberta.encoder.layer.4.intermediate.dense.weight', 'generator.roberta.embeddings.LayerNorm.bias', 'aux_bert.encoder.layer.0.att ...
# - This IS expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing RobertaForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of RobertaForSequenceClassification were not initialized from the model checkpoint at ../models/diffcse-roberta-base-trans and are newly initialized: ['classifier.out_proj.weight', 'classifier.dense.bias', 'classifier.out_proj.bias', 'classifier.dense.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
dataset_test = pd.read_parquet(r'test_result.parquet', engine='fastparquet')
dataset_test
# Out:
#           dataset method                                               text
# 0          archiv  chief  \nThe isotony axiom is natural because we have...  \
# 1          archiv  chief  \nIn the usual situation, all the von Neumann ...
# 2          archiv  chief  \nAt the end of this section, we compare our f...
# 3          archiv  chief  \nBoth of one (unitary) vertex operator algebr...
# 4          archiv  chief  \nFor nets of factors, we have introduced a ne...
# ...           ...    ...                                                ...
# 257450  wikipedia   spin  "Dead Man's Chest" was discharged in the Unite...
# 257451  wikipedia   spin  The wedding of Will Turner and Elizabeth Swann...
# 257452  wikipedia   spin  Will discovers Jack and the group on an island...
# 257453  wikipedia   spin  In Tortuga, Jack enlists another group, includ...
# 257454  wikipedia   spin  Jack arranges the survivors to forsake transpo...
#
#         label  SimCSE  SimCSE_roberta  DiffCSE  DiffCSE_roberta
# 0           0   0.500           0.470    0.595            0.710
# 1           0   0.280           0.375    0.770            0.360
# 2           0   0.355           0.420    0.475            0.325
# 3           0   0.595           0.475    0.670            0.685
# 4           0   0.485           0.590    0.590            0.390
# ...       ...     ...             ...      ...              ...
# 257450      1   0.745           0.695    0.825            0.950
# 257451      1   0.460           0.560    0.485            0.730
# 257452      1   0.395           0.560    0.445            0.545
# 257453      1   0.500           0.640    0.585            0.755
# 257454      1   0.595           0.525    0.540            0.790
#
# [257455 rows x 8 columns]

# %%
dataset_train = pd.read_parquet(r'train_result.parquet', engine='fastparquet')
dataset_train
# Out:
#                dataset method
# 0       wikipediaTrain   spin  \
# 1       wikipediaTrain   spin
# 2       wikipediaTrain   spin
# 3       wikipediaTrain   spin
# 4       wikipediaTrain   spin
# ...                ...    ...
# 200762  wikipediaTrain   spin
# 200763  wikipediaTrain   spin
# 200764  wikipediaTrain   spin
# 200765  wikipediaTrain   spin
# 200766  wikipediaTrain   spin
#
#                                                      text  label  SimCSE
# 0       3D graphics were created using the Nichimen N-...      0   0.160  \
# 1       Miyamoto's guiding design philosophy was to in...      0   0.170
# 2       "Super Mario 64" features more puzzles than ea...      0   0.075
# 3       "Super Mario 64" received widespread critical ...      0   0.080
# 4       The game has been praised in the gaming press,...      0   0.080
# ...                                                   ...    ...     ...
# 200762  A "Roy of the Rovers" PC amusement was dischar...      1   0.945
# 200763  On 29 February 2008 it was reported that Titan...      1   0.905
# 200764  Football-themed stories were a staple of Briti...      1   0.830
# 200765  Roy of the Rovers initially showed up on 11 Se...      1   0.835
# 200766  The funny cartoon was revived in July 1997, pr...      1   0.850
#
#         SimCSE_roberta  DiffCSE  DiffCSE_roberta
# 0                0.080    0.090            0.095
# 1                0.215    0.100            0.155
# 2                0.150    0.110            0.065
# 3                0.115    0.040            0.060
# 4                0.070    0.050            0.090
# ...                ...      ...              ...
# 200762           0.935    0.995            0.970
# 200763           0.825    0.805            0.895
# 200764           0.830    0.875            0.935
# 200765           0.780    0.900            0.700
# 200766           0.825    0.775            0.725
#
# [200767 rows x 8 columns]

# %%
dataset_train, dataset_eval, _, _ = train_test_split(dataset_train, dataset_train, test_size = 0.25,
                                                      shuffle = True, random_state = 42)

# %%
dataset_test['label'] = dataset_test['label'].astype(float)
dataset_train['label'] = dataset_train['label'].astype(float)
dataset_eval['label'] = dataset_eval['label'].astype(float)

# %%
train_texts, train_labels = dataset_train['text'].tolist(),dataset_train['label'].tolist()
test_texts, test_labels = dataset_test['text'].tolist(),dataset_test['label'].tolist()
eval_texts, eval_labels = dataset_eval['text'].tolist(),dataset_eval['label'].tolist()

# %%
tokenizer = AutoTokenizer.from_pretrained("../models/diffcse-roberta-base-trans")
train_encodings = tokenizer(train_texts, return_tensors='pt',
                padding='max_length',
                max_length=512,
                truncation=True)
test_encodings = tokenizer(test_texts, return_tensors='pt',
                padding='max_length',
                max_length=512,
                truncation=True)
eval_encodings = tokenizer(eval_texts, return_tensors='pt',
                padding='max_length',
                max_length=512,
                truncation=True)

# %%
class MyDataset(torch.utils.data.Dataset):
    def __init__(self, encodings, labels):
        self.encodings = encodings
        self.labels = labels

    def __getitem__(self, idx):
        item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
        item['labels'] = torch.tensor(self.labels[idx])
        return item

    def __len__(self):
        return len(self.labels)

# %%
train_dataset = MyDataset(train_encodings, train_labels)
test_dataset = MyDataset(test_encodings, test_labels)
eval_dataset = MyDataset(eval_encodings, eval_labels)

# %%
learning_rate_param = [0.001]
optim_param = ['adamw_torch']#'adafactor'

# %%
trainer = []
result = []
final_lst = []
for lr in learning_rate_param:
    for opt in optim_param:
        #training_args.learning_rate = lr
        training_args.optim = opt
        training_args.per_gpu_train_batch_size = 32
        trainer += [Trainer(
            model=model,
            args=training_args,
            train_dataset=train_dataset,
            eval_dataset=eval_dataset
        )]
for i in range(len(trainer)):
    trainer[i].train()
    lst = []
    result_test_pred = trainer[i].predict(eval_dataset)
    for i in range(len(eval_dataset.labels)):
        lst+=[scipy.special.expit(result_test_pred[0][i][0])]
    final_lst+=[lst]
    result += [pd.DataFrame(zip(eval_dataset.labels,lst),columns = ['true','pred'])]
# Out:
# Using deprecated `--per_gpu_train_batch_size` argument which will be removed in a future version. Using `--per_device_train_batch_size` is preferred.
# Using deprecated `--per_gpu_train_batch_size` argument which will be removed in a future version. Using `--per_device_train_batch_size` is preferred.
# Using deprecated `--per_gpu_train_batch_size` argument which will be removed in a future version. Using `--per_device_train_batch_size` is preferred.
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
#     <div>
#
#       <progress value='16471' max='16471' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [16471/16471 4:53:16, Epoch 7/7]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.002500</td>
#       <td>0.002847</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.002700</td>
#       <td>0.005305</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.001500</td>
#       <td>0.001391</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.000700</td>
#       <td>0.002463</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.000600</td>
#       <td>0.002390</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.000300</td>
#       <td>0.001542</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.000300</td>
#       <td>0.001020</td>
#     </tr>
#   </tbody>
# </table><p>
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '

# %%
res = []
for i in range(len(result)):
    res+=[roc_auc_score(result[i]['true'], result[i]['pred'])]
max_value = max(res)
max_index = res.index(max_value)
max_index
# Out:
# 0

# %%
def find_model(lr_list,optim_list,max_index):
    i = 0
    best_model = []
    for num,lr in enumerate(lr_list):#,0.1]:
        for num_1,opt in enumerate(optim_list):
            print(i,lr,opt)
            if i == max_index:
                best_model= [lr,opt]
                return best_model
            else:
                i+=1

# %%
best_model = find_model(learning_rate_param,optim_param,max_index)
best_model
# Out:
# 0 0.001 adamw_torch
# [0.001, 'adamw_torch']

# %%
result_test_pred = trainer[max_index].predict(test_dataset)
# Out:
# /tmp/job-1412647/ipykernel_153181/3135598630.py:7: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   item = {key: torch.tensor(val[idx]) for key, val in self.encodings.items()}
# /home/sslashinin/.conda/envs/nlp_env/lib/python3.8/site-packages/torch/nn/parallel/_functions.py:68: UserWarning: Was asked to gather along dimension 0, but all input tensors were scalars; will instead unsqueeze and return a vector.
#   warnings.warn('Was asked to gather along dimension 0, but all '

# %%
lst = []
for i in range(len(test_dataset.labels)):
    lst+=[scipy.special.expit(result_test_pred[0][i][0])]
final_res = pd.DataFrame(zip(test_dataset.labels,lst),columns = ['true','pred'])
final_res
# Out:
#         true      pred
# 0        0.0  0.499956
# 1        0.0  0.499948
# 2        0.0  0.499963
# 3        0.0  0.499957
# 4        0.0  0.499952
# ...      ...       ...
# 257450   1.0  0.738444
# 257451   1.0  0.738439
# 257452   1.0  0.738421
# 257453   1.0  0.738419
# 257454   1.0  0.738407
#
# [257455 rows x 2 columns]

# %%
def roc(test_result_old):   
    fpr, tpr, treshold = roc_curve(test_result_old['true'], test_result_old['pred'])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr,
         label=f'ROC (area = %0.2f)' % roc_auc)
    plt.plot([0, 1], [0, 1], color='navy', linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Совмещенные ROC-кривые')
    plt.legend(loc="lower right")
    plt.show()

# %%
roc(final_res)

# %%
final_res
# Out:
#         true      pred
# 0        0.0  0.499956
# 1        0.0  0.499948
# 2        0.0  0.499963
# 3        0.0  0.499957
# 4        0.0  0.499952
# ...      ...       ...
# 257450   1.0  0.738444
# 257451   1.0  0.738439
# 257452   1.0  0.738421
# 257453   1.0  0.738419
# 257454   1.0  0.738407
#
# [257455 rows x 2 columns]

# %%
def confuns_matrix(train_rezalt_old):
    print(f'f1')
    print(f1_score(train_rezalt_old['true'].tolist(), [int(p>0.7) for p in train_rezalt_old['pred']], average='macro'))
    sns.heatmap(metrics.confusion_matrix(train_rezalt_old['true'],[int(p>0.73) for p in train_rezalt_old['pred']]),annot=True,cmap="Blues",square=True)
    plt.ylabel("label")
    plt.xlabel(f"")
    plt.title(f"Confusion matrix")
    plt.show()

# %%
confuns_matrix(final_res)
# Out:
# f1
# 0.8488284150409415
